# %% [markdown]
# <a href="https://colab.research.google.com/github/MaximL98/Manipulated-Reality/blob/master/video_analysis/colab_notebooks/video_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Capstone Project Part I**
# ***This Notebook is the first from three steps, perfom video preprocessing.***

# %% [markdown]
# The following code perfom video preprocessing that includes:
#
#
# *   Face extraction
# *   Frame per second reduction
# *   Setting maximum video length
# *   Resizing images

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/ManipulatedReality/VideoDatasets/Celeb-DF-V2
# Out:
# Celeb-real  Celeb-synthesis  Fake  Real

# %%
# !ls /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2
# Out:
# Celeb-real	       normalized_data_fake   tmp		      val_df_30fps.csv
# Celeb-real-30fps       normalized_data_real   train_df_30fps.csv      val_df_30fps.csv.csv
# Celeb-synthesis        test_df_30fps.csv      train_df_30fps.csv.csv  val_df.csv
# Celeb-synthesis-30fps  test_df_30fps.csv.csv  train_df_30fps.gsheet   val_df.gsheet
# feature_extracted      test_df.csv	      train_df.csv

# %%
# Install face_recognition library
# !pip install face-recognition
# Out:
# Collecting face-recognition
#   Downloading face_recognition-1.3.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting face-recognition-models>=0.3.0 (from face-recognition)
#   Downloading face_recognition_models-0.3.0.tar.gz (100.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 23.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.10/dist-packages (from face-recognition) (8.1.7)
# Requirement already satisfied: dlib>=19.7 in /usr/local/lib/python3.10/dist-packages (from face-recognition) (19.24.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from face-recognition) (1.25.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from face-recognition) (9.4.0)
# Downloading face_recognition-1.3.0-py2.py3-none-any.whl (15 kB)
# Building wheels for collected packages: face-recognition-models
#   Building wheel for face-recognition-models (setup.py) ... done
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566164 sha256=cb62e1d1239ca126d32b5eef9abd2aca2efaae92f8dd9c2a67349121237a649a
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# Installing collected packages: face-recognition-models, face-recognition
# Successfully installed face-recognition-1.3.0 face-recognition-models-0.3.0

# %%
# Import necessary libraries
import cv2
import os
import numpy as np
import face_recognition
import keras
import pandas as pd
import torchvision.transforms as transforms
from pathlib import Path

# %%
def get_video_paths(folder_path):

  video_paths = [] # List to store found video file paths

  # Recursively traverse the directory tree starting from the given folder_path
  for root, _, files in os.walk(folder_path):
    for file in files:
      # Check if the file extension is one of the supported video formats
      if os.path.splitext(file)[1].lower() in ('.mp4', '.avi', '.mov', '.wmv', '.npy'):  # Common video extensions and npy
        video_path = os.path.join(root, file) # Construct the full path to the video file
        video_paths.append(video_path) # Add the video path to the list
  return video_paths

# %%
def face_detection(image_array, width, height):
    # Locate faces in the frame
    face_locations = face_recognition.face_locations(image_array, model='cnn')
    # Empty numpy array to return in case of not faces were detected
    empty_array = np.array([])
    # Check if face was detected in the frame
    if face_locations:
        top, right, bottom, left = face_locations[0]
        # Save the face frame and resize it
        try:
            face_frame = image_array[top:bottom, left:right]
            resized_face_frame = cv2.resize(face_frame, (width, height), interpolation=cv2.INTER_AREA)
            return resized_face_frame

        except IndexError:
            print("Error: Could not extract face due to invalid bounding box coordinates.")
            return empty_array  # Indicate failure

    else:
        print("No faces detected in the image.")
        return empty_array  # Indicate no faces found

# %%
def extract_video_frame(video_path, video_name):
    # Check if file was all ready processed
    if os.path.exists(video_name + "_processed.npy"):
        print(f"Numpy array for this file {video_name} already exists!")
        return

    # Create a VideoCapture object to read the video
    cap = cv2.VideoCapture(video_path)
    # Check if the video was opened successfully
    if not cap.isOpened():
        print("Error opening video!")
        return None

    # Video properties
    width = 224
    height = 224

    # Empty array to store the frames
    frames = []

    print(f'Starting to extract {video_name} file...')

    error_detect = 0

    # Process each frame of the video
    try:
        while True:
            # Capture frame-by-frame
            ret, frame = cap.read()
            # Target time interval between frames in milliseconds
            target_fps = 15
            # In some of the videos in the real dataset are originaly slowed down by x2
            # To deal with that, x2 fps will be taken
            if '#' in video_name:
                target_fps = 30

            subsample_rate = int(1000 / target_fps)  # Convert FPS to milliseconds
            # Move to the next frame based on the subsample rate
            cap.set(cv2.CAP_PROP_POS_MSEC, (cap.get(cv2.CAP_PROP_POS_MSEC) + subsample_rate))
            # Check if the frame was read correctly
            if not ret:
                print("No more frames to capture!")
                break

            # Convert frame to RGB
            frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

            face_frame = face_detection(frame, width, height)

            if face_frame.size == 0:
                error_detect += 1
                if error_detect > 100:
                    break

            if face_frame.size != 0:
                frames.append(face_frame)

            # Maximum seq length
            if len(frames) == 200:
                break

    finally:
        # Release the capture and close all windows
        cap.release()

    # Save the processed frames as npy array
    if video_name:
        print(f"Saving video frame as numpy array as {video_name}_processed.npy")
        np.save(f"{video_name}_processed.npy", frames)

# %%
import time

# Main function
def main(folder_paths, save_folders):

    # For loop, process both real and fake data
    for index in range(len(folder_paths)):
        # Path to folder which contains data
        folder_path = folder_paths[index]
        # Path to folder in which processed data will be saved
        save_folder = save_folders[index]
        # List of availble types in which the data was split
        types = ["train", "test", "val"]
        for type_ in types:
            # Get paths of all videos
            video_paths = get_video_paths(folder_path + '/' + type_)
            # If such folder does not exist, create it
            save_folder_tmp = save_folder  + '/' + type_
            # Initialize index to follow how many videos finished processing
            i = 0
            # Get total number of files in a folder
            num_files = len(video_paths)
            # For smaller model process only 10-20% of the data, for full model 100%
            num_to_process = int(num_files*1)
            # 100% of data
            ## num_to_process = num_files
            # Iterate each video, extract the frames which include faces
            for video_path in video_paths:
                if i == num_to_process:
                    print(f"Reached set limit of {num_to_process} out of {num_files}")
                    break;
                print(f"Video {i + 1}/{len(video_paths)}")
                # Get video name
                video_name = Path(video_path).stem
                video_name = save_folder_tmp + '/' + video_name
                # Preprocesse the video
                start_time = time.time()
                extract_video_frame(video_path=video_path, video_name=video_name)
                print("--- %s seconds ---" % (time.time() - start_time))
                i+=1

# %% [markdown]
# 15fps 200 seq length

# %%
folder_paths = ["/content/drive/MyDrive/ManipulatedReality/VideoDatasets/Celeb-DF-V2/Celeb-real",
                "/content/drive/MyDrive/ManipulatedReality/VideoDatasets/Celeb-DF-V2/Celeb-synthesis"]

save_folders = ["/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-real",
                "/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis"]

# %%
main(folder_paths,save_folders)
# Out:
# Streaming output truncated to the last 5000 lines.
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id17_id20_0000 already exists!
# --- 0.0005486011505126953 seconds ---
# Video 657/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id23_id2_0006 already exists!
# --- 0.0006885528564453125 seconds ---
# Video 658/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id25_id22_0008 already exists!
# --- 0.0001761913299560547 seconds ---
# Video 659/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id33_id37_0007 already exists!
# --- 0.0006990432739257812 seconds ---
# Video 660/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id9_0007 already exists!
# --- 0.00021266937255859375 seconds ---
# Video 661/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id43_id48_0004 already exists!
# --- 0.0005528926849365234 seconds ---
# Video 662/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id56_id49_0003 already exists!
# --- 0.0003921985626220703 seconds ---
# Video 663/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id37_id30_0006 already exists!
# --- 0.0006968975067138672 seconds ---
# Video 664/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id30_0007 already exists!
# --- 0.00021576881408691406 seconds ---
# Video 665/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id13_id10_0015 already exists!
# --- 0.0005459785461425781 seconds ---
# Video 666/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id19_0007 already exists!
# --- 0.0006883144378662109 seconds ---
# Video 667/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id37_id28_0008 already exists!
# --- 0.00022220611572265625 seconds ---
# Video 668/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id37_0006 already exists!
# --- 0.000518798828125 seconds ---
# Video 669/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id31_id35_0003 already exists!
# --- 0.0007035732269287109 seconds ---
# Video 670/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id28_0007 already exists!
# --- 0.00024700164794921875 seconds ---
# Video 671/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id37_0001 already exists!
# --- 0.0007052421569824219 seconds ---
# Video 672/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id30_0009 already exists!
# --- 0.0003540515899658203 seconds ---
# Video 673/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id20_id35_0000 already exists!
# --- 0.0006885528564453125 seconds ---
# Video 674/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id58_id51_0003 already exists!
# --- 0.00019168853759765625 seconds ---
# Video 675/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id56_id54_0006 already exists!
# --- 0.0005366802215576172 seconds ---
# Video 676/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id58_id55_0002 already exists!
# --- 0.0006875991821289062 seconds ---
# Video 677/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id57_id51_0005 already exists!
# --- 0.00018334388732910156 seconds ---
# Video 678/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id57_id51_0008 already exists!
# --- 0.0007114410400390625 seconds ---
# Video 679/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id35_id6_0002 already exists!
# --- 0.00023317337036132812 seconds ---
# Video 680/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id20_id9_0001 already exists!
# --- 0.0009245872497558594 seconds ---
# Video 681/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id9_0001 already exists!
# --- 0.0006759166717529297 seconds ---
# Video 682/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id30_id6_0000 already exists!
# --- 0.0007419586181640625 seconds ---
# Video 683/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id26_id27_0001 already exists!
# --- 0.0002338886260986328 seconds ---
# Video 684/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id34_id31_0003 already exists!
# --- 0.0005819797515869141 seconds ---
# Video 685/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id56_id58_0002 already exists!
# --- 0.0007395744323730469 seconds ---
# Video 686/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id26_id22_0000 already exists!
# --- 0.0002193450927734375 seconds ---
# Video 687/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id4_0005 already exists!
# --- 0.0005600452423095703 seconds ---
# Video 688/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id31_0002 already exists!
# --- 0.0005214214324951172 seconds ---
# Video 689/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id10_id13_0002 already exists!
# --- 0.0007021427154541016 seconds ---
# Video 690/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id33_id29_0006 already exists!
# --- 0.0004036426544189453 seconds ---
# Video 691/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id6_0001 already exists!
# --- 0.0002129077911376953 seconds ---
# Video 692/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id57_id51_0007 already exists!
# --- 0.000186920166015625 seconds ---
# Video 693/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id56_id54_0005 already exists!
# --- 0.0007112026214599609 seconds ---
# Video 694/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id35_id30_0002 already exists!
# --- 0.00022721290588378906 seconds ---
# Video 695/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id8_id5_0007 already exists!
# --- 0.00017714500427246094 seconds ---
# Video 696/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id21_0007 already exists!
# --- 0.0007486343383789062 seconds ---
# Video 697/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id20_id27_0009 already exists!
# --- 0.0001800060272216797 seconds ---
# Video 698/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id26_id25_0006 already exists!
# --- 0.0005271434783935547 seconds ---
# Video 699/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id16_id30_0012 already exists!
# --- 0.0007660388946533203 seconds ---
# Video 700/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id58_id57_0008 already exists!
# --- 0.0001823902130126953 seconds ---
# Video 701/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id42_id41_0000 already exists!
# --- 0.0001990795135498047 seconds ---
# Video 702/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id37_id23_0008 already exists!
# --- 0.0007154941558837891 seconds ---
# Video 703/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id20_0006 already exists!
# --- 0.00018739700317382812 seconds ---
# Video 704/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id34_id33_0009 already exists!
# --- 0.0005478858947753906 seconds ---
# Video 705/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id21_0008 already exists!
# --- 0.0005283355712890625 seconds ---
# Video 706/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id41_id42_0004 already exists!
# --- 0.0005123615264892578 seconds ---
# Video 707/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id38_id31_0006 already exists!
# --- 0.0005271434783935547 seconds ---
# Video 708/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id30_id16_0000 already exists!
# --- 0.0005075931549072266 seconds ---
# Video 709/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id11_id7_0001 already exists!
# --- 0.0007002353668212891 seconds ---
# Video 710/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id29_id30_0006 already exists!
# --- 0.0001811981201171875 seconds ---
# Video 711/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id56_id51_0002 already exists!
# --- 0.0005202293395996094 seconds ---
# Video 712/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id35_id1_0006 already exists!
# --- 0.0005292892456054688 seconds ---
# Video 713/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id27_id24_0003 already exists!
# --- 0.0006842613220214844 seconds ---
# Video 714/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id23_0004 already exists!
# --- 0.0003604888916015625 seconds ---
# Video 715/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id16_id1_0003 already exists!
# --- 0.0006802082061767578 seconds ---
# Video 716/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id28_0009 already exists!
# --- 0.00018405914306640625 seconds ---
# Video 717/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id30_0006 already exists!
# --- 0.0007135868072509766 seconds ---
# Video 718/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id40_id44_0005 already exists!
# --- 0.0001838207244873047 seconds ---
# Video 719/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id17_0003 already exists!
# --- 0.0006995201110839844 seconds ---
# Video 720/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id6_0008 already exists!
# --- 0.00018787384033203125 seconds ---
# Video 721/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id4_0004 already exists!
# --- 0.0005059242248535156 seconds ---
# Video 722/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id35_id29_0006 already exists!
# --- 0.0005247592926025391 seconds ---
# Video 723/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id16_0007 already exists!
# --- 0.000507354736328125 seconds ---
# Video 724/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id16_id2_0002 already exists!
# --- 0.0005211830139160156 seconds ---
# Video 725/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id28_0001 already exists!
# --- 0.0005056858062744141 seconds ---
# Video 726/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id40_id41_0002 already exists!
# --- 0.0005183219909667969 seconds ---
# Video 727/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id7_id13_0002 already exists!
# --- 0.0006895065307617188 seconds ---
# Video 728/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id57_id52_0003 already exists!
# --- 0.0005242824554443359 seconds ---
# Video 729/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id16_id20_0001 already exists!
# --- 0.0003829002380371094 seconds ---
# Video 730/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id28_0003 already exists!
# --- 0.0003464221954345703 seconds ---
# Video 731/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id27_id20_0004 already exists!
# --- 0.000518798828125 seconds ---
# Video 732/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id23_id30_0009 already exists!
# --- 0.0005037784576416016 seconds ---
# Video 733/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id16_id26_0010 already exists!
# --- 0.000522613525390625 seconds ---
# Video 734/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id27_id21_0004 already exists!
# --- 0.000507354736328125 seconds ---
# Video 735/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id2_0006 already exists!
# --- 0.0002200603485107422 seconds ---
# Video 736/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id57_id49_0002 already exists!
# --- 0.0007605552673339844 seconds ---
# Video 737/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id58_id49_0002 already exists!
# --- 0.0001761913299560547 seconds ---
# Video 738/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id57_id58_0003 already exists!
# --- 0.0007026195526123047 seconds ---
# Video 739/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id35_0002 already exists!
# --- 0.0003643035888671875 seconds ---
# Video 740/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id3_id23_0003 already exists!
# --- 0.0005156993865966797 seconds ---
# Video 741/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id56_id53_0003 already exists!
# --- 0.00016736984252929688 seconds ---
# Video 742/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id19_id23_0001 already exists!
# --- 0.0007026195526123047 seconds ---
# Video 743/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id20_0006 already exists!
# --- 0.0001876354217529297 seconds ---
# Video 744/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id57_id50_0006 already exists!
# --- 0.0007100105285644531 seconds ---
# Video 745/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id31_0006 already exists!
# --- 0.000194549560546875 seconds ---
# Video 746/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id37_0005 already exists!
# --- 0.0006718635559082031 seconds ---
# Video 747/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id1_0004 already exists!
# --- 0.0006952285766601562 seconds ---
# Video 748/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id13_id10_0014 already exists!
# --- 0.00019168853759765625 seconds ---
# Video 749/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id31_id30_0000 already exists!
# --- 0.0005691051483154297 seconds ---
# Video 750/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id2_id20_0007 already exists!
# --- 0.0005390644073486328 seconds ---
# Video 751/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id37_id9_0002 already exists!
# --- 0.0007393360137939453 seconds ---
# Video 752/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id24_id26_0003 already exists!
# --- 0.00019478797912597656 seconds ---
# Video 753/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id1_0006 already exists!
# --- 0.0005099773406982422 seconds ---
# Video 754/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id26_id16_0006 already exists!
# --- 0.0005245208740234375 seconds ---
# Video 755/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id16_0006 already exists!
# --- 0.0005116462707519531 seconds ---
# Video 756/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id31_0002 already exists!
# --- 0.000690460205078125 seconds ---
# Video 757/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id7_id12_0002 already exists!
# --- 0.00020813941955566406 seconds ---
# Video 758/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id23_0005 already exists!
# --- 0.0005924701690673828 seconds ---
# Video 759/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id8_id0_0007 already exists!
# --- 0.0006630420684814453 seconds ---
# Video 760/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id30_0001 already exists!
# --- 0.00078582763671875 seconds ---
# Video 761/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id1_0005 already exists!
# --- 0.00041365623474121094 seconds ---
# Video 762/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id56_id53_0008 already exists!
# --- 0.0006971359252929688 seconds ---
# Video 763/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id20_id28_0000 already exists!
# --- 0.00022721290588378906 seconds ---
# Video 764/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id3_0004 already exists!
# --- 0.0007226467132568359 seconds ---
# Video 765/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id23_id26_0001 already exists!
# --- 0.0005331039428710938 seconds ---
# Video 766/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id24_id28_0003 already exists!
# --- 0.0002143383026123047 seconds ---
# Video 767/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id58_id56_0007 already exists!
# --- 0.0007393360137939453 seconds ---
# Video 768/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id37_id20_0004 already exists!
# --- 0.0005774497985839844 seconds ---
# Video 769/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id57_id52_0006 already exists!
# --- 0.00020194053649902344 seconds ---
# Video 770/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id20_id4_0003 already exists!
# --- 0.0007684230804443359 seconds ---
# Video 771/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id26_0007 already exists!
# --- 0.00019097328186035156 seconds ---
# Video 772/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id8_id2_0002 already exists!
# --- 0.0005183219909667969 seconds ---
# Video 773/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id31_id21_0008 already exists!
# --- 0.0006997585296630859 seconds ---
# Video 774/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id2_0001 already exists!
# --- 0.00018858909606933594 seconds ---
# Video 775/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id37_0004 already exists!
# --- 0.0007169246673583984 seconds ---
# Video 776/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id40_id43_0009 already exists!
# --- 0.0003991127014160156 seconds ---
# Video 777/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id56_id55_0002 already exists!
# --- 0.00019097328186035156 seconds ---
# Video 778/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id37_0006 already exists!
# --- 0.0007216930389404297 seconds ---
# Video 779/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id33_id34_0006 already exists!
# --- 0.00020933151245117188 seconds ---
# Video 780/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id16_id9_0013 already exists!
# --- 0.0007088184356689453 seconds ---
# Video 781/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id17_0000 already exists!
# --- 0.0002048015594482422 seconds ---
# Video 782/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id4_0006 already exists!
# --- 0.0004172325134277344 seconds ---
# Video 783/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id8_id3_0002 already exists!
# --- 0.0002143383026123047 seconds ---
# Video 784/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id20_0008 already exists!
# --- 0.0007131099700927734 seconds ---
# Video 785/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id17_id30_0002 already exists!
# --- 0.0005602836608886719 seconds ---
# Video 786/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id38_id34_0007 already exists!
# --- 0.00021982192993164062 seconds ---
# Video 787/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id58_id54_0003 already exists!
# --- 0.0007085800170898438 seconds ---
# Video 788/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id7_id12_0004 already exists!
# --- 0.0005309581756591797 seconds ---
# Video 789/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id8_id5_0002 already exists!
# --- 0.0003833770751953125 seconds ---
# Video 790/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id31_id29_0006 already exists!
# --- 0.00036334991455078125 seconds ---
# Video 791/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id56_id53_0006 already exists!
# --- 0.0006883144378662109 seconds ---
# Video 792/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id34_id30_0009 already exists!
# --- 0.000362396240234375 seconds ---
# Video 793/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id26_id1_0009 already exists!
# --- 0.0005965232849121094 seconds ---
# Video 794/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id28_id22_0006 already exists!
# --- 0.0003867149353027344 seconds ---
# Video 795/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id34_id33_0003 already exists!
# --- 0.0002117156982421875 seconds ---
# Video 796/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id24_id28_0000 already exists!
# --- 0.00019598007202148438 seconds ---
# Video 797/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id30_id21_0004 already exists!
# --- 0.0007762908935546875 seconds ---
# Video 798/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id38_id35_0001 already exists!
# --- 0.0002338886260986328 seconds ---
# Video 799/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id40_id43_0002 already exists!
# --- 0.0001990795135498047 seconds ---
# Video 800/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id37_id26_0008 already exists!
# --- 0.0007500648498535156 seconds ---
# Video 801/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id1_0008 already exists!
# --- 0.0005409717559814453 seconds ---
# Video 802/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id30_id9_0002 already exists!
# --- 0.00036025047302246094 seconds ---
# Video 803/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id43_id48_0006 already exists!
# --- 0.00035834312438964844 seconds ---
# Video 804/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id3_id6_0009 already exists!
# --- 0.0008420944213867188 seconds ---
# Video 805/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id2_id1_0003 already exists!
# --- 0.00017499923706054688 seconds ---
# Video 806/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id2_id6_0008 already exists!
# --- 0.0007002353668212891 seconds ---
# Video 807/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id31_id6_0007 already exists!
# --- 0.00019860267639160156 seconds ---
# Video 808/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id31_id30_0005 already exists!
# --- 0.0006899833679199219 seconds ---
# Video 809/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id20_id19_0009 already exists!
# --- 0.0001690387725830078 seconds ---
# Video 810/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id19_id20_0006 already exists!
# --- 0.0007455348968505859 seconds ---
# Video 811/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id23_id22_0003 already exists!
# --- 0.0002040863037109375 seconds ---
# Video 812/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id28_0000 already exists!
# --- 0.0005459785461425781 seconds ---
# Video 813/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id30_id2_0009 already exists!
# --- 0.000705718994140625 seconds ---
# Video 814/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id0_0006 already exists!
# --- 0.0001888275146484375 seconds ---
# Video 815/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id28_0008 already exists!
# --- 0.0005319118499755859 seconds ---
# Video 816/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id17_0000 already exists!
# --- 0.0005159378051757812 seconds ---
# Video 817/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id30_id31_0006 already exists!
# --- 0.0005221366882324219 seconds ---
# Video 818/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id7_id12_0007 already exists!
# --- 0.0006949901580810547 seconds ---
# Video 819/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id6_id0_0002 already exists!
# --- 0.00019693374633789062 seconds ---
# Video 820/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id16_id31_0002 already exists!
# --- 0.0007047653198242188 seconds ---
# Video 821/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id1_id31_0006 already exists!
# --- 0.00018167495727539062 seconds ---
# Video 822/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id57_id51_0002 already exists!
# --- 0.0005254745483398438 seconds ---
# Video 823/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id3_0006 already exists!
# --- 0.000522613525390625 seconds ---
# Video 824/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id1_0008 already exists!
# --- 0.0006861686706542969 seconds ---
# Video 825/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id2_id6_0005 already exists!
# --- 0.0001862049102783203 seconds ---
# Video 826/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id20_id4_0006 already exists!
# --- 0.0007064342498779297 seconds ---
# Video 827/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id9_id20_0004 already exists!
# --- 0.0001938343048095703 seconds ---
# Video 828/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id40_id44_0001 already exists!
# --- 0.0006983280181884766 seconds ---
# Video 829/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id28_id38_0007 already exists!
# --- 0.000194549560546875 seconds ---
# Video 830/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id28_id38_0004 already exists!
# --- 0.0005831718444824219 seconds ---
# Video 831/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id20_id32_0001 already exists!
# --- 0.0005574226379394531 seconds ---
# Video 832/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id28_id38_0000 already exists!
# --- 0.00021266937255859375 seconds ---
# Video 833/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id34_0001 already exists!
# --- 0.0007071495056152344 seconds ---
# Video 834/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id38_0007 already exists!
# --- 0.0001914501190185547 seconds ---
# Video 835/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id34_0007 already exists!
# --- 0.0007359981536865234 seconds ---
# Video 836/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id29_0007 already exists!
# --- 0.0007064342498779297 seconds ---
# Video 837/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id34_0004 already exists!
# --- 0.0002014636993408203 seconds ---
# Video 838/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id29_0009 already exists!
# --- 0.0008375644683837891 seconds ---
# Video 839/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id20_id38_0000 already exists!
# --- 0.00018715858459472656 seconds ---
# Video 840/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id33_0000 already exists!
# --- 0.0004589557647705078 seconds ---
# Video 841/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id23_id38_0004 already exists!
# --- 0.0002346038818359375 seconds ---
# Video 842/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id29_0000 already exists!
# --- 0.0005671977996826172 seconds ---
# Video 843/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id23_id33_0002 already exists!
# --- 0.000762939453125 seconds ---
# Video 844/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id21_id38_0000 already exists!
# --- 0.00020623207092285156 seconds ---
# Video 845/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id23_id34_0003 already exists!
# --- 0.0005862712860107422 seconds ---
# Video 846/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id23_id38_0003 already exists!
# --- 0.0005676746368408203 seconds ---
# Video 847/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id23_id29_0009 already exists!
# --- 0.0006892681121826172 seconds ---
# Video 848/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id26_id33_0004 already exists!
# --- 0.0001964569091796875 seconds ---
# Video 849/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id29_id26_0007 already exists!
# --- 0.0007185935974121094 seconds ---
# Video 850/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id29_id21_0005 already exists!
# --- 0.0001957416534423828 seconds ---
# Video 851/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id29_id20_0008 already exists!
# --- 0.0007004737854003906 seconds ---
# Video 852/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id28_id29_0009 already exists!
# --- 0.0005464553833007812 seconds ---
# Video 853/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id28_id34_0003 already exists!
# --- 0.0005986690521240234 seconds ---
# Video 854/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id29_id23_0006 already exists!
# --- 0.0006010532379150391 seconds ---
# Video 855/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id28_id32_0004 already exists!
# --- 0.0006108283996582031 seconds ---
# Video 856/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id28_id33_0008 already exists!
# --- 0.0005662441253662109 seconds ---
# Video 857/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id29_id28_0003 already exists!
# --- 0.0005624294281005859 seconds ---
# Video 858/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id28_id32_0005 already exists!
# --- 0.0007226467132568359 seconds ---
# Video 859/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id29_id26_0000 already exists!
# --- 0.0002009868621826172 seconds ---
# Video 860/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id33_id23_0006 already exists!
# --- 0.0002090930938720703 seconds ---
# Video 861/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id32_id20_0000 already exists!
# --- 0.0007765293121337891 seconds ---
# Video 862/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id32_id23_0007 already exists!
# --- 0.00018715858459472656 seconds ---
# Video 863/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id32_id26_0000 already exists!
# --- 0.0005383491516113281 seconds ---
# Video 864/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id33_id20_0001 already exists!
# --- 0.0007069110870361328 seconds ---
# Video 865/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id32_id26_0002 already exists!
# --- 0.00034999847412109375 seconds ---
# Video 866/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id32_id20_0007 already exists!
# --- 0.0005209445953369141 seconds ---
# Video 867/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id33_id23_0008 already exists!
# --- 0.0006835460662841797 seconds ---
# Video 868/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id32_id23_0009 already exists!
# --- 0.00020194053649902344 seconds ---
# Video 869/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id32_id23_0002 already exists!
# --- 0.0008296966552734375 seconds ---
# Video 870/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id33_id20_0003 already exists!
# --- 0.00020194053649902344 seconds ---
# Video 871/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id38_id20_0002 already exists!
# --- 0.0005400180816650391 seconds ---
# Video 872/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id37_id16_0001 already exists!
# --- 0.0006918907165527344 seconds ---
# Video 873/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id38_id20_0000 already exists!
# --- 0.00019311904907226562 seconds ---
# Video 874/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id38_id28_0009 already exists!
# --- 0.00070953369140625 seconds ---
# Video 875/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id38_id28_0004 already exists!
# --- 0.00018668174743652344 seconds ---
# Video 876/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id38_id26_0006 already exists!
# --- 0.00046896934509277344 seconds ---
# Video 877/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id34_id26_0008 already exists!
# --- 0.00022935867309570312 seconds ---
# Video 878/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id22_id27_0005 already exists!
# --- 0.0004138946533203125 seconds ---
# Video 879/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id1_id9_0007 already exists!
# --- 0.0007882118225097656 seconds ---
# Video 880/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id24_id20_0009 already exists!
# --- 0.0003731250762939453 seconds ---
# Video 881/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id16_id20_0012 already exists!
# --- 0.0005753040313720703 seconds ---
# Video 882/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id10_id13_0001 already exists!
# --- 0.0005388259887695312 seconds ---
# Video 883/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id11_id7_0008 already exists!
# --- 0.0005471706390380859 seconds ---
# Video 884/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id29_id32_0000 already exists!
# --- 0.00028586387634277344 seconds ---
# Video 885/1131
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/id16_id20_0000 already exists!
# ...
# --- 0.0009431838989257812 seconds ---
# Video 1116/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id53_id57_0004 already exists!
# --- 0.0009403228759765625 seconds ---
# Video 1117/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id4_id0_0002 already exists!
# --- 0.0009636878967285156 seconds ---
# Video 1118/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id4_id6_0000 already exists!
# --- 0.0009884834289550781 seconds ---
# Video 1119/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id48_id39_0005 already exists!
# --- 0.0009322166442871094 seconds ---
# Video 1120/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id47_id39_0004 already exists!
# --- 0.000982522964477539 seconds ---
# Video 1121/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id13_id7_0015 already exists!
# --- 0.0009942054748535156 seconds ---
# Video 1122/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id49_id55_0001 already exists!
# --- 0.0009434223175048828 seconds ---
# Video 1123/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id46_id47_0000 already exists!
# --- 0.0009388923645019531 seconds ---
# Video 1124/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id4_id20_0007 already exists!
# --- 0.0009298324584960938 seconds ---
# Video 1125/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id26_id9_0002 already exists!
# --- 0.0009276866912841797 seconds ---
# Video 1126/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id45_id41_0001 already exists!
# --- 0.0009386539459228516 seconds ---
# Video 1127/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id52_id57_0002 already exists!
# --- 0.0009365081787109375 seconds ---
# Video 1128/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id53_id55_0005 already exists!
# --- 0.0009329319000244141 seconds ---
# Video 1129/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id55_id57_0002 already exists!
# --- 0.00022602081298828125 seconds ---
# Video 1130/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id46_id45_0004 already exists!
# --- 0.0017201900482177734 seconds ---
# Video 1131/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id50_id52_0007 already exists!
# --- 0.0009889602661132812 seconds ---
# Video 1132/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id4_id6_0002 already exists!
# --- 0.0009560585021972656 seconds ---
# Video 1133/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id30_id37_0007 already exists!
# --- 0.0009629726409912109 seconds ---
# Video 1134/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id46_id45_0009 already exists!
# --- 0.0009546279907226562 seconds ---
# Video 1135/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id47_id46_0007 already exists!
# --- 0.0009496212005615234 seconds ---
# Video 1136/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id51_id57_0004 already exists!
# --- 0.0009510517120361328 seconds ---
# Video 1137/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id37_id29_0001 already exists!
# --- 0.0009455680847167969 seconds ---
# Video 1138/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id51_id57_0008 already exists!
# --- 0.0009539127349853516 seconds ---
# Video 1139/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id44_id42_0003 already exists!
# --- 0.0009455680847167969 seconds ---
# Video 1140/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id52_id54_0007 already exists!
# --- 0.0009784698486328125 seconds ---
# Video 1141/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id51_id56_0004 already exists!
# --- 0.0010690689086914062 seconds ---
# Video 1142/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id47_id44_0000 already exists!
# --- 0.0010654926300048828 seconds ---
# Video 1143/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id55_id51_0009 already exists!
# --- 0.0010230541229248047 seconds ---
# Video 1144/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id55_id51_0008 already exists!
# --- 0.0009679794311523438 seconds ---
# Video 1145/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id44_id42_0005 already exists!
# --- 0.0009443759918212891 seconds ---
# Video 1146/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id47_id42_0004 already exists!
# --- 0.0009410381317138672 seconds ---
# Video 1147/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id50_id49_0003 already exists!
# --- 0.0009667873382568359 seconds ---
# Video 1148/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id48_id41_0009 already exists!
# --- 0.0002334117889404297 seconds ---
# Video 1149/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id47_id46_0006 already exists!
# --- 0.0016384124755859375 seconds ---
# Video 1150/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id53_id50_0008 already exists!
# --- 0.0010082721710205078 seconds ---
# Video 1151/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id4_id1_0006 already exists!
# --- 0.0010044574737548828 seconds ---
# Video 1152/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id45_id42_0000 already exists!
# --- 0.0009646415710449219 seconds ---
# Video 1153/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id49_id50_0000 already exists!
# --- 0.0009443759918212891 seconds ---
# Video 1154/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id46_id39_0004 already exists!
# --- 0.0009427070617675781 seconds ---
# Video 1155/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id4_id2_0004 already exists!
# --- 0.0009613037109375 seconds ---
# Video 1156/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id49_id50_0005 already exists!
# --- 0.0009596347808837891 seconds ---
# Video 1157/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id52_id56_0001 already exists!
# --- 0.0009520053863525391 seconds ---
# Video 1158/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id48_id47_0007 already exists!
# --- 0.0009725093841552734 seconds ---
# Video 1159/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id54_id51_0001 already exists!
# --- 0.0022614002227783203 seconds ---
# Video 1160/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id44_id43_0004 already exists!
# --- 0.0007545948028564453 seconds ---
# Video 1161/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id46_id47_0002 already exists!
# --- 0.0009493827819824219 seconds ---
# Video 1162/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id45_id46_0008 already exists!
# --- 0.0009577274322509766 seconds ---
# Video 1163/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id53_id58_0002 already exists!
# --- 0.0009877681732177734 seconds ---
# Video 1164/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id49_id57_0000 already exists!
# --- 0.0009431838989257812 seconds ---
# Video 1165/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id49_id50_0006 already exists!
# --- 0.0009465217590332031 seconds ---
# Video 1166/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id45_id39_0004 already exists!
# --- 0.0009686946868896484 seconds ---
# Video 1167/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id16_id9_0011 already exists!
# --- 0.0010449886322021484 seconds ---
# Video 1168/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id49_id52_0006 already exists!
# --- 0.0009999275207519531 seconds ---
# Video 1169/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id46_id39_0009 already exists!
# --- 0.0009512901306152344 seconds ---
# Video 1170/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id48_id39_0009 already exists!
# --- 0.0007069110870361328 seconds ---
# Video 1171/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id47_id43_0000 already exists!
# --- 0.00058746337890625 seconds ---
# Video 1172/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id49_id53_0008 already exists!
# --- 0.0007407665252685547 seconds ---
# Video 1173/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id46_id40_0004 already exists!
# --- 0.00019240379333496094 seconds ---
# Video 1174/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id4_id0_0004 already exists!
# --- 0.0005476474761962891 seconds ---
# Video 1175/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id51_id56_0000 already exists!
# --- 0.00021338462829589844 seconds ---
# Video 1176/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id40_id48_0004 already exists!
# --- 0.0008261203765869141 seconds ---
# Video 1177/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id51_id54_0001 already exists!
# --- 0.00020432472229003906 seconds ---
# Video 1178/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id48_id43_0005 already exists!
# --- 0.0006124973297119141 seconds ---
# Video 1179/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id45_id43_0007 already exists!
# --- 0.0007801055908203125 seconds ---
# Video 1180/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id54_id49_0008 already exists!
# --- 0.00018715858459472656 seconds ---
# Video 1181/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id46_id45_0002 already exists!
# --- 0.0005853176116943359 seconds ---
# Video 1182/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id4_id0_0008 already exists!
# --- 0.0005543231964111328 seconds ---
# Video 1183/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id16_id28_0002 already exists!
# --- 0.0005474090576171875 seconds ---
# Video 1184/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id44_id42_0002 already exists!
# --- 0.0007584095001220703 seconds ---
# Video 1185/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id53_id49_0003 already exists!
# --- 0.00045228004455566406 seconds ---
# Video 1186/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id51_id58_0001 already exists!
# --- 0.00020885467529296875 seconds ---
# Video 1187/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id52_id55_0005 already exists!
# --- 0.0006802082061767578 seconds ---
# Video 1188/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id52_id50_0002 already exists!
# --- 0.0005471706390380859 seconds ---
# Video 1189/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id49_id54_0004 already exists!
# --- 0.0005688667297363281 seconds ---
# Video 1190/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id45_id42_0004 already exists!
# --- 0.0005431175231933594 seconds ---
# Video 1191/1191
# Numpy array for this file /content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/id44_id39_0003 already exists!
# --- 0.0007269382476806641 seconds ---

# %%
# Function to label data, after it was splitted
# If data splitting was made not using "split_train_test_data" then this function is needed to label data
def label_data(real_train_folder, real_test_folder, real_val_folder,
              fake_train_folder, fake_test_folder, fake_val_folder):

    # Lists to store file paths and labels
    real_train_paths = get_video_paths(real_train_folder)
    real_test_paths = get_video_paths(real_test_folder)
    real_val_paths = get_video_paths(real_val_folder)

    fake_train_paths = get_video_paths(fake_train_folder)
    fake_test_paths = get_video_paths(fake_test_folder)
    fake_val_paths = get_video_paths(fake_val_folder)

    # Assign labels (1 for real, 0 for fake)
    real_label = 1
    fake_label = 0

    # Create DataFrames for real videos
    train_df_real = pd.DataFrame({"video_path": real_train_paths, "label": [real_label] * len(real_train_paths)})
    test_df_real = pd.DataFrame({"video_path": real_test_paths, "label": [real_label] * len(real_test_paths)})
    val_df_real = pd.DataFrame({"video_path": real_val_paths, "label": [real_label] * len(real_val_paths)})

    # Create DataFrames for fake videos
    train_df_fake = pd.DataFrame({"video_path": fake_train_paths, "label": [fake_label] * len(fake_train_paths)})
    test_df_fake = pd.DataFrame({"video_path": fake_test_paths, "label": [fake_label] * len(fake_test_paths)})
    val_df_fake = pd.DataFrame({"video_path": fake_val_paths, "label": [fake_label] * len(fake_val_paths)})

    # Combine real and fake DataFrames for each split
    train_df = pd.concat([train_df_real, train_df_fake], ignore_index=True)
    test_df = pd.concat([test_df_real, test_df_fake], ignore_index=True)
    val_df = pd.concat([val_df_real, val_df_fake], ignore_index=True)

    # Check if DataFrames were converted to csv already, comment does lines if want to update csv's
    if os.path.exists(paths_to_csv['train_df']+'.csv') and os.path.exists(paths_to_csv['test_df']+'.csv') and os.path.exists(paths_to_csv['val_df']+'.csv'):
        print("DataFrames already converted to csv's files...")
        # Return DataFrames of train, test and valuation
        return train_df, test_df, val_df

    # Save DataFrame as csv file
    train_df.to_csv(paths_to_csv['train_df']+'.csv', sep=',', index=False, encoding='utf-8')
    test_df.to_csv(paths_to_csv['test_df']+'.csv', sep=',', index=False, encoding='utf-8')
    val_df.to_csv(paths_to_csv['val_df']+'.csv', sep=',', index=False, encoding='utf-8')

    # Return DataFrames of train, test and valuation
    return train_df, test_df, val_df

# %%
real_video_folder_train = '/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-real/train/'
real_video_folder_test = '/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-real/test/'
real_video_folder_val = '/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-real/val/'

fake_video_folder_train = '/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/train'
fake_video_folder_test = '/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/test/'
fake_video_folder_val = '/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/Celeb-synthesis/val/'

# %%
paths_to_csv = {
    'train_df': '/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/train_df_full',
    'test_df': '/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/test_df_full',
    'val_df': '/content/drive/MyDrive/ManipulatedReality/NumpyConvertedDatabases/Celeb-DF-v2/val_df_full'
}

# %%
# Label the data
label_data(real_train_folder=real_video_folder_train, real_test_folder=real_video_folder_test, real_val_folder=real_video_folder_val,
           fake_train_folder=fake_video_folder_train, fake_test_folder=fake_video_folder_test, fake_val_folder=fake_video_folder_val)
# Out:
# (                                             video_path  label
#  0     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  1     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  2     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  3     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  4     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  ...                                                 ...    ...
#  8944  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  8945  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  8946  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  8947  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  8948  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#
#  [8949 rows x 2 columns],
#                                               video_path  label
#  0     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  1     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  2     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  3     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  4     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  ...                                                 ...    ...
#  3004  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  3005  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  3006  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  3007  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  3008  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#
#  [3009 rows x 2 columns],
#                                               video_path  label
#  0     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  1     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  2     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  3     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  4     /content/drive/MyDrive/ManipulatedReality/Nump...      1
#  ...                                                 ...    ...
#  3064  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  3065  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  3066  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  3067  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#  3068  /content/drive/MyDrive/ManipulatedReality/Nump...      0
#
#  [3069 rows x 2 columns])
